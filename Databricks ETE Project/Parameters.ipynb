# %%
datasets = [
    {
        "fileName" : "orders"
    },
    {
        "fileName" : "customers"
    },
    {
        "fileName" : "products"
    },
    {
        "fileName" : "regions"
    }
]

# %%
dbutils.jobs.taskValues.set(key = "my_arr", value = datasets)
